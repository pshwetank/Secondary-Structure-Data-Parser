# %%
import numpy as np
import math
import string
import csv

# %% [markdown]
# # For Question 2:

# %%
prot = "CTCCCHHHHHEEHHHEHCCCCTHEHHEHHHHHHHHHHHHHHEEHHHHHHEHEHHEEEEEHHTHHHHHHHHEEEHHHHHHHHEEEHHHHHEEEEEEEEEHEEHEEEEEEHHHHTHHHEHEEHTTEECCHTTHEEEEEEHHHHHHHHHTHHHHHHHHTHHHHHHHEEEEHHHHHEEEEHEHHHHHHHHHHHHHHHEEHHHHHHHHHHHHTHHHHEHC"

# %%
start = prot[0]
cnt = 0
pos = 0
csvForm1 = []
for i in range(len(prot)):
  if prot[i] == start:
    cnt += 1
  if prot[i] != start:
    #print(start + " : "+ str(pos) + " - " + str(i-1)+ ". Length = "+ str(cnt))
    csvForm1.append([start,str(pos+1) + " - " + str(i),str(cnt)])
    pos = i
    start = prot[i]
    cnt = 1  
  if i == (len(prot)-1):
    #print(start + " : "+ str(pos) + " - " + str(i-1)+ ". Length = "+ str(cnt))
    csvForm1.append([start,str(pos+1) + " - " + str(i),str(cnt)])

# %%
with open('q32.csv', 'w') as csvFile:
    writer = csv.writer(csvFile)
    writer.writerows(csvForm1)
csvFile.close()

# %%
from google.colab import files
files.download('q32.csv')

# %% [markdown]
# # For Question 3:

# %%
text = '''
   1 M    0.53*   0.20    0.19    H |    0.57*   0.26    0.26    H
   2 L    0.46*   0.20    0.12    H |    0.55*   0.22    0.25    H
   3 E    0.33*   0.24    0.19    H |    0.46*   0.18    0.35    H
   4 L    0.33    0.13    0.41*   C |    0.37    0.11    0.52*   C
   5 L    0.19    0.02    0.82*   C |    0.31    0.07    0.68*   C
   6 P    0.16    0.04    0.83*   C |    0.28    0.06    0.75*   C
   7 T    0.39    0.06    0.62*   C |    0.34    0.06    0.64*   C
   8 A    0.29    0.14    0.41*   C |    0.36    0.09    0.54*   C
   9 V    0.21    0.12    0.53*   C |    0.32    0.09    0.60*   C
  10 E    0.20    0.09    0.68*   C |    0.30    0.10    0.65*   C
  11 G    0.27    0.07    0.54*   C |    0.31    0.12    0.63*   C
  12 V    0.24    0.04    0.67*   C |    0.27    0.14    0.62*   C
  13 S    0.29*   0.19    0.28    H |    0.28    0.20    0.51*   C
  14 Q    0.19    0.19    0.44*   C |    0.25    0.27    0.42*   C
  15 A    0.22    0.57*   0.23    E |    0.22    0.38*   0.33    E
  16 Q    0.04    0.24    0.79*   C |    0.18    0.27    0.49*   C
  17 I    0.16    0.29    0.41*   C |    0.18    0.25    0.54*   C
  18 T    0.03    0.19    0.89*   C |    0.12    0.15    0.73*   C
  19 G    0.08    0.04    0.89*   C |    0.10    0.09    0.83*   C
  20 R    0.08    0.02    0.96*   C |    0.11    0.06    0.87*   C
  21 P    0.09    0.03    0.84*   C |    0.13    0.08    0.82*   C
  22 E    0.23    0.07    0.57*   C |    0.21    0.17    0.59*   C
  23 W    0.22    0.28*   0.18    E |    0.34    0.36*   0.24    E
  24 I    0.38    0.62*   0.10    E |    0.49    0.58*   0.06    E
 108 L    0.81*   0.11    0.13    H |    0.89*   0.06    0.10    H
 109 D    0.86*   0.06    0.16    H |    0.89*   0.05    0.12    H
 110 L    0.85*   0.03    0.19    H |    0.88*   0.04    0.16    H
 111 A    0.73*   0.08    0.21    H |    0.85*   0.04    0.18    H
 112 L    0.61*   0.13    0.22    H |    0.84*   0.04    0.19    H
 113 L    0.50*   0.11    0.34    H |    0.81*   0.04    0.24    H
 114 V    0.31    0.17    0.37*   C |    0.74*   0.04    0.30    H
 115 D    0.50*   0.05    0.44    H |    0.68*   0.03    0.41    H
 116 A    0.53    0.01    0.71*   C |    0.56    0.02    0.58*   C
 117 D    0.38    0.02    0.82*   C |    0.42    0.02    0.73*   C
 118 Q    0.57    0.01    0.82*   C |    0.34    0.03    0.73*   C
 119 G    0.46    0.03    0.52*   C |    0.34    0.06    0.60*   C
 120 T    0.35    0.14    0.50*   C |    0.34    0.15    0.37*   C
 121 I    0.37    0.72*   0.05    E |    0.36    0.46*   0.11    E
 122 L    0.32    0.67*   0.12    E |    0.39    0.64*   0.06    E
 123 A    0.33    0.57*   0.09    E |    0.39    0.65*   0.06    E
 124 L    0.28    0.53*   0.19    E |    0.35    0.49*   0.12    E
 125 V    0.23    0.11    0.54*   C |    0.25    0.29    0.34*   C
 126 G    0.33    0.06    0.55*   C |    0.25    0.13    0.58*   C
 127 A    0.32    0.01    0.82*   C |    0.16    0.08    0.78*   C
 128 D    0.18    0.09    0.62*   C |    0.12    0.11    0.78*   C
 129 G    0.13    0.15    0.64*   C |    0.14    0.18    0.65*   C
 130 I    0.15    0.27    0.43*   C |    0.17    0.42*   0.35    E
 131 M    0.13    0.84*   0.11    E |    0.19    0.65*   0.15    E
 132 I    0.22    0.53*   0.22    E |    0.14    0.68*   0.17    E
 133 G    0.13    0.41    0.44*   C |    0.15    0.48*   0.30    E
 134 T    0.07    0.25    0.79*   C |    0.12    0.40    0.47*   C
 135 G    0.12    0.31*   0.27    E |    0.15    0.44*   0.42    E
 136 L    0.20    0.08    0.69*   C |    0.19    0.26    0.49*   C
 137 V    0.20*   0.20    0.17    H |    0.24    0.32    0.37*   C
 138 G    0.18    0.33    0.45*   C |    0.25    0.32    0.36*   C
 139 A    0.44*   0.22    0.22    H |    0.32    0.40*   0.24    E
 140 L    0.30    0.45*   0.18    E |    0.35    0.44*   0.19    E
 141 T    0.22    0.30    0.43*   C |    0.32    0.36*   0.23    E
 142 K    0.40*   0.33    0.14    H |    0.39*   0.36    0.19    H
 143 V    0.30    0.17    0.35*   C |    0.30    0.30    0.33*   C
 144 Y    0.35*   0.26    0.30    H |    0.26    0.32    0.33*   C
 145 S    0.23    0.27    0.45*   C |    0.21    0.30    0.35*   C
 146 Y    0.17    0.45*   0.41    E |    0.19    0.41*   0.28    E
 147 R    0.38    0.43*   0.15    E |    0.21    0.50*   0.19    E
 148 F    0.38    0.38*   0.10    E |    0.21    0.57*   0.14    E
 149 V    0.24    0.70*   0.10    E |    0.21    0.72*   0.08    E
 192 V    0.39    0.74*   0.03    E |    0.29    0.65*   0.06    E
 193 V    0.32    0.66*   0.07    E |    0.30    0.66*   0.07    E
 194 L    0.24    0.48*   0.21    E |    0.28    0.56*   0.11    E
 195 W    0.09    0.41    0.51*   C |    0.21    0.38*   0.27    E
 196 S    0.13    0.15    0.58*   C |    0.17    0.23    0.53*   C
 197 A    0.23    0.06    0.65*   C |    0.13    0.15    0.70*   C
 198 Y    0.17    0.07    0.71*   C |    0.11    0.12    0.76*   C
 199 P    0.28    0.05    0.72*   C |    0.11    0.20    0.67*   C
 200 V    0.36    0.38*   0.10    E |    0.14    0.53*   0.32    E
 201 V    0.27    0.78*   0.06    E |    0.15    0.81*   0.09    E
 202 W    0.11    0.89*   0.09    E |    0.14    0.88*   0.05    E
 203 L    0.05    0.81*   0.30    E |    0.14    0.85*   0.08    E
 204 I    0.14    0.54*   0.29    E |    0.12    0.73*   0.19    E
 205 G    0.13    0.09    0.72*   C |    0.10    0.34    0.54*   C
 206 S    0.10    0.02    0.93*   C |    0.08    0.14    0.81*   C
 207 E    0.09    0.06    0.86*   C |    0.07    0.10    0.88*   C
 208 G    0.03    0.05    0.98*   C |    0.07    0.08    0.90*   C
 209 A    0.10    0.03    0.83*   C |    0.08    0.11    0.87*   C
 210 G    0.04    0.12    0.79*   C |    0.12    0.15    0.76*   C
 211 I    0.09    0.30    0.49*   C |    0.18    0.31    0.47*   C
 212 V    0.05    0.62*   0.32    E |    0.20    0.41*   0.31    E
 213 P    0.09    0.20    0.59*   C |    0.27    0.29    0.35*   C
 214 L    0.32    0.15    0.36*   C |    0.37*   0.23    0.37    H
 215 N    0.14    0.11    0.72*   C |    0.41    0.14    0.42*   C
 216 I    0.55*   0.03    0.21    H |    0.59*   0.15    0.27    H
 217 E    0.45*   0.07    0.31    H |    0.67*   0.10    0.24    H
 218 T    0.71*   0.11    0.18    H |    0.73*   0.12    0.17    H
 219 L    0.74*   0.24    0.11    H |    0.74*   0.14    0.12    H
 220 L    0.72*   0.20    0.13    H |    0.77*   0.15    0.09    H
 221 F    0.73*   0.52    0.04    H |    0.77*   0.25    0.04    H
 222 M    0.61*   0.46    0.04    H |    0.75*   0.24    0.05    H
 223 V    0.61*   0.32    0.04    H |    0.76*   0.21    0.06    H
 224 L    0.56*   0.29    0.13    H |    0.70*   0.12    0.13    H
 225 D    0.39    0.08    0.53*   C |    0.63*   0.06    0.28    H
 226 V    0.54*   0.08    0.27    H |    0.64*   0.05    0.33    H
 227 S    0.39    0.04    0.59*   C |    0.60*   0.04    0.43    H
 228 A    0.40    0.08    0.49*   C |    0.60*   0.05    0.40    H
 229 K    0.46*   0.18    0.27    H |    0.57*   0.06    0.38    H
 230 V    0.51    0.02    0.68*   C |    0.52*   0.05    0.47    H
 231 G    0.61*   0.08    0.37    H |    0.50*   0.06    0.42    H
 232 F    0.47*   0.15    0.38    H |    0.46*   0.11    0.33    H
 233 G    0.41    0.44*   0.13    E |    0.44*   0.32    0.14    H
 234 L    0.26    0.55*   0.09    E |    0.50*   0.49    0.06    H
 235 I    0.48    0.78*   0.02    E |    0.52    0.61*   0.04    E
 236 L    0.33    0.51*   0.18    E |    0.47*   0.47    0.07    H
 237 L    0.54*   0.12    0.22    H |    0.47*   0.25    0.18    H
 238 R    0.62*   0.09    0.37    H |    0.40*   0.14    0.36    H
 239 S    0.25    0.12    0.67*   C |    0.31    0.10    0.52*   C
 240 R    0.36    0.09    0.41*   C |    0.34    0.12    0.50*   C
 241 A    0.25    0.22    0.45*   C |    0.35    0.14    0.45*   C
 242 I    0.22    0.26    0.41*   C |    0.32    0.16    0.44*   C
 243 F    0.25    0.22    0.49*   C |    0.26    0.13    0.57*   C
 244 G    0.12    0.08    0.77*   C |    0.20    0.09    0.73*   C
 245 E    0.09    0.06    0.82*   C |    0.18    0.09    0.80*   C
 246 A    0.06    0.06    0.82*   C |    0.15    0.08    0.84*   C
 247 E    0.05    0.01    0.90*   C |    0.14    0.06    0.87*   C
 248 A    0.07    0.01    0.93*   C |    0.13    0.06    0.89*   C
 249 P    0.05    0.01    0.96*   C |    0.13    0.06    0.90*   C
 250 E    0.10    0.01    0.96*   C |    0.13    0.06    0.89*   C
 251 P    0.04    0.03    0.96*   C |    0.13    0.07    0.88*   C
 252 S    0.10    0.03    0.92*   C |    0.14    0.07    0.87*   C
 253 A    0.06    0.03    0.91*   C |    0.14    0.08    0.86*   C
 254 G    0.12    0.05    0.86*   C |    0.14    0.08    0.87*   C
 255 D    0.10    0.02    0.93*   C |    0.13    0.09    0.85*   C
 256 G    0.11    0.10    0.73*   C |    0.17    0.12    0.76*   C
 257 A    0.10    0.19    0.80*   C |    0.21    0.17    0.64*   C
 258 A    0.15    0.27    0.39*   C |    0.23    0.24    0.50*   C
 259 A    0.18    0.13    0.69*   C |    0.22    0.17    0.64*   C
 260 T    0.23    0.13    0.67*   C |    0.19    0.14    0.69*   C
 261 S    0.25    0.09    0.76*   C |    0.21    0.13    0.71*   C
 262 D    0.31    0.06    0.73*   C |    0.26    0.16    0.67*   C'''

# %%
list_line = [y for y in (x.strip() for x in text.splitlines()) if y]
parsed = []
for i in range(0,len(list_line)):
  parsed.append(list_line[i][-1])

# %%
start = parsed[0]
cnt = 0
pos = 0
csvForm2 = []
for i in range(len(parsed)):
  if parsed[i] == start:
    cnt += 1
  if parsed[i] != start:
    #print(start + " : "+ str(pos) + " - " + str(i-1)+ ". Length = "+ str(cnt))
    csvForm2.append([start,str(pos+1) + " - " + str(i),str(cnt)])
    pos = i
    start = parsed[i]
    cnt = 1 
  if i == (len(parsed)-1):
    #print(start + " : "+ str(pos) + " - " + str(i-1)+ ". Length = "+ str(cnt))
    csvForm2.append([start,str(pos+1) + " - " + str(i),str(cnt)])

# %%
with open('nn2.csv', 'w') as csvFile:
    writer = csv.writer(csvFile)
    writer.writerows(csvForm2)
csvFile.close()

# %%
from google.colab import files
files.download('nn2.csv')

# %%
list_line
